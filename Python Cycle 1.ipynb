# %%
a=1
print("the value of",a,"is of the type",type(a))
b="hello"
print("the value of",b,"is of the type",type(b))
c=3.14
print("the value of",c,"is of the type",type(c))
d=2j
print("the value of",d,"is of the type",type(d))
e={"ads","web","python"}
print("the value of",e,"is of the type",type(e))
f=("ads","web","python")
print("the value of",f,"is of the type",type(f))
g=["ads","web","python"]
print("the value of",g,"is of the type",type(g))
h=range(5)
print("the value of",h,"is of the type",type(h))
i=True
print("the value of",i,"is of the type",type(i))
# Out:
# the value of 1 is of the type <class 'int'>
# the value of hello is of the type <class 'str'>
# the value of 3.14 is of the type <class 'float'>
# the value of 2j is of the type <class 'complex'>
# the value of {'web', 'python', 'ads'} is of the type <class 'set'>
# the value of ('ads', 'web', 'python') is of the type <class 'tuple'>
# the value of ['ads', 'web', 'python'] is of the type <class 'list'>
# the value of range(0, 5) is of the type <class 'range'>
# the value of True is of the type <class 'bool'>

# %%
print("Hello, World !")
# Out:
# Hello, World !

# %%
x=int(input("enter a integer value :"))
print(x)
# Out:
# enter a integer value :11
# 11

# %%
x=int(input("enter the value of first integer :"))
y=int(input("enter the value of second integer :"))
z=x+y
print("sum :",z)
# Out:
# enter the value of first integer :13
# enter the value of second integer :12
# sum : 25

# %%
x=float(input("enter the first float value :"))
y=float(input("enter the second float value :"))
z=x*y
print("product :",z)
# Out:
# enter the first float value :3.9
# enter the second float value :8.7
# product : 33.93

# %%
u=int(input("enter the first value :"))
v=int(input("enter the second value :"))
q=u//v
print("quotient :",q)
r=u%v
print("remainder :",r)
# Out:
# enter the first value :17
# enter the second value :12
# quotient : 1
# remainder : 5

# %%
a=float(input("enter the first number :"))
b=float(input("enter the second number :"))
print("value of the first number before swapping :",a)
print("value of the second number before swapping :",b)
c=a
a=b
b=c
print("value of the first number after swapping :",a)
print("value of the second number after swapping :",b)
# Out:
# enter the first number :3.0
# enter the second number :7.0
# value of the first number before swapping : 3.0
# value of the second number before swapping : 7.0
# value of the first number after swapping : 7.0
# value of the second number after swapping : 3.0

# %%
a=int(input("enter the number :"))
b = a%2
if b==0:
  print(a,"is an even number.")
else:
    print(a,"is an odd number.")
# Out:
# enter the number :101
# 101 is an odd number.

# %%
ch=input("enter the character :")
if (ch=='A'or ch=='E' or ch=='I' or ch=='O' or ch=='U'or ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u'):
  print(ch,"is a vowel.")
else:
  print(ch,"is a consonant.")
# Out:
# enter the character :c
# c is a consonant.

# %%
a=float(input("enter the first number :"))
b=float(input("enter the second number :"))
c=float(input("enter the third number :"))
if (a>b) and (a>c):
  print(a,"is largest number.")
elif (b>a) and (b>c):
  print(b,"is the largest number.")
else:
  print(c,"is the largest number.")
# Out:
# enter the first number :8.7
# enter the second number :7.8
# enter the third number :11.2
# 11.2 is the largest number.

# %%
yr=int(input("enter the year :"))
if ((yr%400==0) or ((yr%4==0) and (yr%100!=0))):
 print(yr,"is a leap year.")
else:
  print(yr,"is not a leap year.")
# Out:
# enter the year :1995
# 1995 is not a leap year.

# %%
x=int(input("enter the number:"))
if x>0:
  print(x,"is a positive number.")
else:
  print(x,"is a negative number.")
# Out:
# enter the number:-7
# -7 is a negative number.

# %%
n=int(input("enter the number :"))
if n<0:
  print("print a positive number.")
else:
  sum=0
  while (n>0):
    sum+=n
    n-=1
print("sum of natural numbers is",sum)
# Out:
# enter the number :7
# sum of natural numbers is 28

# %%
n=int(input("enter the number :"))
fact=1
for i in range(1,n+1):
  fact=fact*i
print("factorial of",n,"is",fact)
# Out:
# enter the number :6
# factorial of 6 is 720

# %%
x=int(input("show the multiplication table of ?"))
for i in range(1,11):
  print(x,'x',i,'=',x*i)
# Out:
# show the multiplication table of ?11
# 11 x 1 = 11
# 11 x 2 = 22
# 11 x 3 = 33
# 11 x 4 = 44
# 11 x 5 = 55
# 11 x 6 = 66
# 11 x 7 = 77
# 11 x 8 = 88
# 11 x 9 = 99
# 11 x 10 = 110

# %%
n=int(input("enter the number :"))
x,y =0,1
count=0
if n<=0:
  print("enter a positive number.")
elif n==1:
  print("fibonacci sequence upto",n,":")
  print(x)
else:
  print("fibonacci sequence :")
  while count<n:
    print(x)
    z=x+y
    x=y
    y=z
    count+=1
# Out:
# enter the number :9
# fibonacci sequence :
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
def find_lcm(x, y):
   if x > y:
       greater = x
   else:
       greater = y
   while(True):
       if((greater % x == 0) and (greater % y == 0)):
           lcm = greater
           break
       greater += 1
   return lcm
a=int(input("enter the value of first number :"))
b=int(input("enter the value of second number :"))
print("the L.C.M. is", find_lcm(a,b))
# Out:
# enter the value of first number :22
# enter the value of second number :33
# the L.C.M. is 66

# %%
n=int(input("enter the number :"))
count=0
while (n>0):
    count=count+1
    n=n//10
print("the number of digits in the given number is :",count)
# Out:
# enter the number :100
# the number of digits in the given number is : 3

# %%
x=int(input("enter the number to be reversed :"))
rev=0
while x>0:
  rev=(rev*10)+(x%10)
  x=x//10
print("reverse is",rev)
# Out:
# enter the number to be reversed :47
# reverse is 74

# %%
n=int(input("enter the positive number :"))
e=int(input("enter the value of exponent :"))
p=1
for i in range(1,e+1):
  p=p*n
print("the power of",n,"^",e,"is",p)
# Out:
# enter the positive number :5
# enter the value of exponent :3
# the power of 5 ^ 3 is 125

# %%
n=int(input("enter the number :"))
rev=0
temp=n
while (temp > 0):
    r=temp%10
    rev=(rev*10)+r
    temp=temp//10
print("reverse of this given number is",rev)
if (n==rev):
    print(n,"is a palindrome number")
else:
    print(n,"is not a palindrome number")
# Out:
# enter the number :7654
# reverse of this given number is 4567
# 7654 is not a palindrome number
